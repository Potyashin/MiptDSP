# %%
# !git clone https://github.com/sp-uhh/sgmse.git
# Out:
# Cloning into 'sgmse'...
# remote: Enumerating objects: 801, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 801 (delta 168), reused 140 (delta 139), pack-reused 596
# Receiving objects: 100% (801/801), 3.69 MiB | 15.83 MiB/s, done.
# Resolving deltas: 100% (414/414), done.

# %%
# !pip3 install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 29.0 MB/s eta 0:00:00
# ...

# %%
# !virtualenv myvenv
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 1737ms
#   creator CPython3Posix(dest=/content/myvenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.3.1, setuptools==69.0.2, wheel==0.42.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/myvenv/bin/activate; pip install -r sgmse/requirements.txt

# %%
# !source /content/myvenv/bin/activate; python sgmse/enhancement.py --N 50 --snr 0.33 --test_dir /content/drive/MyDrive/DSP/ --enhanced_dir /content/drive/MyDrive/DSP/enhanced --ckpt /content/drive/MyDrive/DSP/epoch=326-step=408750.ckpt
# Out:
# 100% 1/1 [03:21<00:00, 201.43s/it]
